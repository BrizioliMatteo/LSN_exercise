# %% [markdown]
# ## <span style="color:brown"> Python Exercise 11 </span>
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# Le reti di cui trattiamo sono reti supervisionate, ovvero si cerca di costruire un modello e quindi i suoi parametri, a partire da un data set di training, con il quale si vuole fare previsioni su dati.
#
# Il neurone è l'unità base d una rete neurale, si tratta di un oggette che ha in ingresso diversi input $x_1,\dots,x_N$ e ad ogni input assegna un peso $w_1 \dots w_N$, ovvero numeri reali che esprimono l'importanza dell'input rispetto all'output. Definisce a questo punto una variabile somma su tutti gli input $net=\sum_{i=0}^{N}w_ix_i$. Nel caso di un perceptron l'output del neurono sarà o $0$ o $1$ a seconda che $net-b$ sia minore o maggiore $0$. Dove $b$ è chiamato *bias* che di fatto è una misura di quanto facilmente un certo neurone si attiva (anch'esso è un parametro del neurone).Se vogliamo invece che l'apprendimento sia tale, occorre a volte considerare delle funzioni di attivazioni più complesse, infatti un piccolo cambiamento dei pesi e dei bias con dei perceptrons potrebbe portare ad un output completamente diverso.
#
# Una rete consite in un insieme di ingressi (input layer), uno o più strati nascosti di neuroni (hidden layers) e un insieme di neuroni in uscita (output layer).

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Proprio per come è definito un neurone perceptrone si può pensare che esso sia in grado di eseguire un fit lineare ovvero, se ho un solo input in entrate esso equivale ad un semplice modello di regressione: $wx+b$.

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect


import numpy as np

# generate training inputs


np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.2 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
from math import sin

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects


model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()

# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Train on 500 samples, validate on 50 samples
# Epoch 1/30
# 500/500 [==============================] - 0s 475us/sample - loss: 2.2538 - mean_squared_error: 2.2538 - val_loss: 2.5078 - val_mean_squared_error: 2.5078
# Epoch 2/30
# 500/500 [==============================] - 0s 64us/sample - loss: 1.8385 - mean_squared_error: 1.8385 - val_loss: 2.0815 - val_mean_squared_error: 2.0815
# Epoch 3/30
# 500/500 [==============================] - 0s 58us/sample - loss: 1.5873 - mean_squared_error: 1.5873 - val_loss: 1.7945 - val_mean_squared_error: 1.7945
# Epoch 4/30
# 500/500 [==============================] - 0s 63us/sample - loss: 1.4223 - mean_squared_error: 1.4223 - val_loss: 1.6031 - val_mean_squared_error: 1.6031
# Epoch 5/30
# 500/500 [==============================] - 0s 42us/sample - loss: 1.3120 - mean_squared_error: 1.3120 - val_loss: 1.4745 - val_mean_squared_error: 1.4745
# Epoch 6/30
# 500/500 [==============================] - 0s 54us/sample - loss: 1.2357 - mean_squared_error: 1.2357 - val_loss: 1.3776 - val_mean_squared_error: 1.3776
# Epoch 7/30
# 500/500 [==============================] - 0s 67us/sample - loss: 1.1786 - mean_squared_error: 1.1786 - val_loss: 1.3053 - val_mean_squared_error: 1.3053
# Epoch 8/30
# 500/500 [==============================] - 0s 61us/sample - loss: 1.1349 - mean_squared_error: 1.1349 - val_loss: 1.2542 - val_mean_squared_error: 1.2542
# Epoch 9/30
# 500/500 [==============================] - 0s 62us/sample - loss: 1.1027 - mean_squared_error: 1.1027 - val_loss: 1.2183 - val_mean_squared_error: 1.2183
# Epoch 10/30
# 500/500 [==============================] - 0s 49us/sample - loss: 1.0778 - mean_squared_error: 1.0778 - val_loss: 1.1912 - val_mean_squared_error: 1.1912
# Epoch 11/30
# 500/500 [==============================] - 0s 66us/sample - loss: 1.0581 - mean_squared_error: 1.0581 - val_loss: 1.1732 - val_mean_squared_error: 1.1732
# Epoch 12/30
# 500/500 [==============================] - 0s 40us/sample - loss: 1.0426 - mean_squared_error: 1.0426 - val_loss: 1.1578 - val_mean_squared_error: 1.1578
# Epoch 13/30
# 500/500 [==============================] - 0s 62us/sample - loss: 1.0292 - mean_squared_error: 1.0292 - val_loss: 1.1444 - val_mean_squared_error: 1.1444
# Epoch 14/30
# 500/500 [==============================] - 0s 51us/sample - loss: 1.0193 - mean_squared_error: 1.0193 - val_loss: 1.1355 - val_mean_squared_error: 1.1355
# Epoch 15/30
# 500/500 [==============================] - 0s 65us/sample - loss: 1.0108 - mean_squared_error: 1.0108 - val_loss: 1.1301 - val_mean_squared_error: 1.1301
# Epoch 16/30
# 500/500 [==============================] - 0s 56us/sample - loss: 1.0050 - mean_squared_error: 1.0050 - val_loss: 1.1231 - val_mean_squared_error: 1.1231
# Epoch 17/30
# 500/500 [==============================] - 0s 48us/sample - loss: 0.9991 - mean_squared_error: 0.9991 - val_loss: 1.1186 - val_mean_squared_error: 1.1186
# Epoch 18/30
# 500/500 [==============================] - 0s 62us/sample - loss: 0.9956 - mean_squared_error: 0.9956 - val_loss: 1.1207 - val_mean_squared_error: 1.1207
# Epoch 19/30
# 500/500 [==============================] - 0s 67us/sample - loss: 0.9924 - mean_squared_error: 0.9924 - val_loss: 1.1206 - val_mean_squared_error: 1.1206
# Epoch 20/30
# 500/500 [==============================] - 0s 65us/sample - loss: 0.9895 - mean_squared_error: 0.9895 - val_loss: 1.1188 - val_mean_squared_error: 1.1188
# Epoch 21/30
# 500/500 [==============================] - 0s 66us/sample - loss: 0.9872 - mean_squared_error: 0.9872 - val_loss: 1.1197 - val_mean_squared_error: 1.1197
# Epoch 22/30
# 500/500 [==============================] - 0s 51us/sample - loss: 0.9860 - mean_squared_error: 0.9860 - val_loss: 1.1152 - val_mean_squared_error: 1.1152
# Epoch 23/30
# 500/500 [==============================] - 0s 54us/sample - loss: 0.9840 - mean_squared_error: 0.9840 - val_loss: 1.1160 - val_mean_squared_error: 1.1160
# Epoch 24/30
# 500/500 [==============================] - 0s 49us/sample - loss: 0.9828 - mean_squared_error: 0.9828 - val_loss: 1.1160 - val_mean_squared_error: 1.1160
# Epoch 25/30
# 500/500 [==============================] - 0s 61us/sample - loss: 0.9826 - mean_squared_error: 0.9826 - val_loss: 1.1190 - val_mean_squared_error: 1.1190
# Epoch 26/30
# 500/500 [==============================] - 0s 48us/sample - loss: 0.9815 - mean_squared_error: 0.9815 - val_loss: 1.1145 - val_mean_squared_error: 1.1145
# Epoch 27/30
# 500/500 [==============================] - 0s 61us/sample - loss: 0.9809 - mean_squared_error: 0.9809 - val_loss: 1.1147 - val_mean_squared_error: 1.1147
# Epoch 28/30
# 500/500 [==============================] - 0s 63us/sample - loss: 0.9809 - mean_squared_error: 0.9809 - val_loss: 1.1132 - val_mean_squared_error: 1.1132
# Epoch 29/30
# 500/500 [==============================] - 0s 54us/sample - loss: 0.9799 - mean_squared_error: 0.9799 - val_loss: 1.1163 - val_mean_squared_error: 1.1163
# Epoch 30/30
# 500/500 [==============================] - 0s 53us/sample - loss: 0.9796 - mean_squared_error: 0.9796 - val_loss: 1.1185 - val_mean_squared_error: 1.1185

# %%
# return weights
model.get_weights()

# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy', score[1])

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])


# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()


x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 50/50 [==============================] - 0s 37us/sample - loss: 1.1185 - mean_squared_error: 1.1185
#
# Test loss: 1.1185487174987794
# Test accuracy 1.1185488
# 50/50 [==============================] - 0s 80us/sample - loss: 0.0145 - mean_squared_error: 0.0145
#
# Test loss: 0.014521954357624054
# Test accuracy: 0.014521954

# %% [markdown]
# Si nota come sia l'aumento del numero di epoche così come l'aumento del numero di dati di train migliorano i risultati dell'operazion. Tuttavia, l'aumento del numero dei dati di training è il parametro che maggiormente influenza e migliora l'apprendimento, per un numero di epoche sufficientemente grande. Infatti, andando a guardare la funzione costo si nota come dopo un certo numero di epoche il model loss tende a rimanere costante cioè la rete non riesce più ad imparare. Si noti invece che grandi valori di sigma, ovvero grande rumore, determina una diminuizione della capacità di apprendimento.
#
#
# I risultati ottenuti sono stati infatti ottenuti solamente cambiando, rispetto al codice originale, il numero di punti di training $N_t=500$, il numero di punti di validation $N_v=50$, che in genere si impone essere $1/10$ dei punti di training, e infine il rumore sui data con $\sigma=0.2$.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# In order to make practice with NN, explore reasonable different choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Make graphs comparing fits for different NNs.
# Check your NN models by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
def poli3(x):
  return 4.-3.*x-2.*(x)**2+3*x**3

np.random.seed(0)
x_train = np.random.uniform(-1., 1., 6000)
x_valid = np.random.uniform(-1., 1., 600)
x_valid.sort()
y_target = poli3(x_valid)

sigma = 0.2 ##noise
y_train = np.random.normal(poli3(x_train), sigma)
y_valid = np.random.normal(poli3(x_valid), sigma)

plt.figure()
plt.plot(x_valid,y_target)
plt.scatter(x_valid, y_valid, color = 'r')
plt.grid(True)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(10, input_shape=(1,), activation='tanh'))#numero di neuroni nel primo "hidden layer" e 1 parametro di input
model.add(Dense(25, activation='tanh'))
model.add(Dense(50, activation='tanh'))
model.add(Dense(1))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()

history = model.fit(x=x_train, y=y_train, batch_size=50, epochs=100, shuffle=True,validation_data=(x_valid,y_valid))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_10 (Dense)             (None, 25)                275
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                1300
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 1,646
# Trainable params: 1,646
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6000 samples, validate on 600 samples
# Epoch 1/100
# 6000/6000 [==============================] - 0s 57us/sample - loss: 0.9429 - mean_squared_error: 0.9429 - val_loss: 0.3257 - val_mean_squared_error: 0.3257
# Epoch 2/100
# 6000/6000 [==============================] - 0s 21us/sample - loss: 0.3118 - mean_squared_error: 0.3118 - val_loss: 0.2514 - val_mean_squared_error: 0.2514
# Epoch 3/100
# 6000/6000 [==============================] - 0s 25us/sample - loss: 0.2341 - mean_squared_error: 0.2341 - val_loss: 0.1829 - val_mean_squared_error: 0.1829
# Epoch 4/100
# 6000/6000 [==============================] - 0s 31us/sample - loss: 0.1672 - mean_squared_error: 0.1672 - val_loss: 0.1310 - val_mean_squared_error: 0.1310
# Epoch 5/100
# 6000/6000 [==============================] - 0s 33us/sample - loss: 0.1245 - mean_squared_error: 0.1245 - val_loss: 0.1053 - val_mean_squared_error: 0.1053
# Epoch 6/100
# 6000/6000 [==============================] - 0s 31us/sample - loss: 0.1037 - mean_squared_error: 0.1037 - val_loss: 0.0926 - val_mean_squared_error: 0.0926
# Epoch 7/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0931 - mean_squared_error: 0.0931 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Epoch 8/100
# 6000/6000 [==============================] - 0s 23us/sample - loss: 0.0862 - mean_squared_error: 0.0862 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 9/100
# 6000/6000 [==============================] - 0s 22us/sample - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.0778 - val_mean_squared_error: 0.0778
# Epoch 10/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.
100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0414 - mean_squared_error: 0.0414 - val_loss: 0.0430 - val_mean_squared_error: 0.0430
# Epoch 90/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0441 - val_mean_squared_error: 0.0441
# Epoch 91/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0413 - mean_squared_error: 0.0413 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Epoch 92/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0413 - mean_squared_error: 0.0413 - val_loss: 0.0435 - val_mean_squared_error: 0.0435
# Epoch 93/100
# 6000/6000 [==============================] - 0s 25us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Epoch 94/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Epoch 95/100
# 6000/6000 [==============================] - 0s 23us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0429 - val_mean_squared_error: 0.0429
# Epoch 96/100
# 6000/6000 [==============================] - 0s 20us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0426 - val_mean_squared_error: 0.0426
# Epoch 97/100
# 6000/6000 [==============================] - 0s 23us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0433 - val_mean_squared_error: 0.0433
# Epoch 98/100
# 6000/6000 [==============================] - 0s 27us/sample - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0425 - val_mean_squared_error: 0.0425
# Epoch 99/100
# 6000/6000 [==============================] - 0s 28us/sample - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0426 - val_mean_squared_error: 0.0426
# Epoch 100/100
# 6000/6000 [==============================] - 0s 24us/sample - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 0.0440 - val_mean_squared_error: 0.0440

# %%
score = model.evaluate(x_valid, y_valid, batch_size=50,verbose=1)

print()
print('Test loss:', score[0])
print('Test Accuracy:',score[1])

score = model.evaluate(x_valid, y_target, batch_size=50,verbose=1)

print()
print('Test loss:', score[0])
print('Test Accuracy:',score[1])


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best'); plt.show()


x_new=np.arange(-1.5,1.5,0.1)
x_predicted = np.random.uniform(-3, 3, 200)
y_predicted = model.predict(x_predicted)

y_new = poli3(x_new)

plt.scatter(x_predicted, y_predicted,color='r')
x_predicted.sort()
plt.plot(x_new, y_new)
plt.grid(True);plt.show()


plt.show()
# Out:
# 600/600 [==============================] - 0s 14us/sample - loss: 0.0440 - mean_squared_error: 0.0440
#
# Test loss: 0.04398976235340039
# Test Accuracy: 0.04398976
# 600/600 [==============================] - 0s 25us/sample - loss: 0.0025 - mean_squared_error: 0.0025
#
# Test loss: 0.0024830360719837095
# Test Accuracy: 0.0024830361

# %% [markdown]
# Sebbene la funzione sia un polinomio di grado $3$ e quindi ci si aspetterebbe che bastino soltanto $4$ parametri in realtà la rete ha bisogno di molti più parametri a causa della non linearità della funzione. Aumentare il numero di parametri significa inserire un maggior numero di neuroni e di layers e sicuramente aiuta a fittare la curva tuttavia si ha il rischio di un overfitting, ovvero dell'aggiunta d troppi parametri. E' evidente che gioca un ruolo molto importante la funzione di attivazione, infatti lavorando con lo stesso numeri di neuroni e funzioni di attivazione diverse si nota come la funzione *Relu* non sia in grado di generare delle curve lisce, a differenza invece della *sigmoide* o della *tanh*. D'altra parte la *sigmoide* essendo una funzione più soft non riesce bene a seguire bene le variazioni della funzione. Nell'esercizio si sono utilizzati dei layers con funzione di attivazione *tanh*.
#
#
# Infine si nota come il modello si adatti bene solamente alla regione di dati su cui è avvenuto il training perdendo totalmente potere predittivo per dati fuori dal range: $[-1,1]$.

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %%
from mpl_toolkits.mplot3d import Axes3D
from math import sin

n_train=5000
n_valid=500


x_valid=np.zeros((n_valid,2))
x_train=np.zeros((n_train,2))
z_valid=np.zeros(n_valid)
z_target=np.zeros(n_valid)
z_train=np.zeros(n_train)

np.random.seed(0)


sigma=0.2
for i in range(n_valid):
    x_valid[i,0] = np.random.uniform(-3./2, 3./2.)
    x_valid[i,1] = np.random.uniform(-3./2, 3./2.)
    z_target[i] = sin(x_valid[i,0]**2+x_valid[i,1]**2)
    z_valid[i] =  np.random.normal(np.sin(x_valid[i,0]**2+x_valid[i,1]**2), sigma)

    
for i in range(n_train): 
    x_train[i,0] = np.random.uniform(-3./2, 3./2.)
    x_train[i,1] = np.random.uniform(-3./2, 3./2.)
    z_train[i] =  np.random.normal(sin(x_train[i,0]**2+x_train[i,1]**2), sigma)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_trisurf(x_valid[:,0],x_valid[:,1], z_valid, cmap='viridis', edgecolor = 'none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(40,20)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(12, input_shape=(2,), activation='relu'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
#sgd = optimizers.SGD(lr=0.01, decay = 1e-6, momentum=0.9, nesterov=True)
#keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

history = model.fit(x=x_train, y=z_train, batch_size=50, epochs=100, shuffle=True,validation_data=(x_valid,z_valid))
# Out:
# Train on 5000 samples, validate on 500 samples
# Epoch 1/100
# 5000/5000 [==============================] - 0s 81us/sample - loss: 0.2074 - mean_squared_error: 0.2074 - val_loss: 0.1999 - val_mean_squared_error: 0.1999
# Epoch 2/100
# 5000/5000 [==============================] - 0s 37us/sample - loss: 0.1776 - mean_squared_error: 0.1776 - val_loss: 0.1943 - val_mean_squared_error: 0.1943
# Epoch 3/100
# 5000/5000 [==============================] - 0s 34us/sample - loss: 0.1741 - mean_squared_error: 0.1741 - val_loss: 0.1891 - val_mean_squared_error: 0.1891
# Epoch 4/100
# 5000/5000 [==============================] - 0s 50us/sample - loss: 0.1708 - mean_squared_error: 0.1708 - val_loss: 0.1847 - val_mean_squared_error: 0.1847
# Epoch 5/100
# 5000/5000 [==============================] - 0s 50us/sample - loss: 0.1677 - mean_squared_error: 0.1677 - val_loss: 0.1820 - val_mean_squared_error: 0.1820
# Epoch 6/100
100
# 5000/5000 [==============================] - 0s 32us/sample - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0581 - val_mean_squared_error: 0.0581
# Epoch 88/100
# 5000/5000 [==============================] - 0s 31us/sample - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0579 - val_mean_squared_error: 0.0579
# Epoch 89/100
# 5000/5000 [==============================] - 0s 33us/sample - loss: 0.0535 - mean_squared_error: 0.0535 - val_loss: 0.0582 - val_mean_squared_error: 0.0582
# Epoch 90/100
# 5000/5000 [==============================] - 0s 33us/sample - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0578 - val_mean_squared_error: 0.0578
# Epoch 91/100
# 5000/5000 [==============================] - 0s 32us/sample - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0576 - val_mean_squared_error: 0.0576
# Epoch 92/100
# 5000/5000 [==============================] - 0s 35us/sample - loss: 0.0535 - mean_squared_error: 0.0535 - val_loss: 0.0578 - val_mean_squared_error: 0.0578
# Epoch 93/100
# 5000/5000 [==============================] - 0s 37us/sample - loss: 0.0535 - mean_squared_error: 0.0535 - val_loss: 0.0579 - val_mean_squared_error: 0.0579
# Epoch 94/100
# 5000/5000 [==============================] - 0s 35us/sample - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0573 - val_mean_squared_error: 0.0573
# Epoch 95/100
# 5000/5000 [==============================] - 0s 32us/sample - loss: 0.0535 - mean_squared_error: 0.0535 - val_loss: 0.0578 - val_mean_squared_error: 0.0578
# Epoch 96/100
# 5000/5000 [==============================] - 0s 31us/sample - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0578 - val_mean_squared_error: 0.0578
# Epoch 97/100
# 5000/5000 [==============================] - 0s 35us/sample - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0572 - val_mean_squared_error: 0.0572
# Epoch 98/100
# 5000/5000 [==============================] - 0s 31us/sample - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0574 - val_mean_squared_error: 0.0574
# Epoch 99/100
# 5000/5000 [==============================] - 0s 32us/sample - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 0.0576 - val_mean_squared_error: 0.0576
# Epoch 100/100
# 5000/5000 [==============================] - 0s 32us/sample - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 0.0578 - val_mean_squared_error: 0.0578

# %%
score = model.evaluate(x_valid, z_valid, batch_size=50,verbose=1)

print()
print('Test loss:', score[0])
print('Test Accuracy:',score[1])

score = model.evaluate(x_valid, z_target, batch_size=50,verbose=1)

print()
print('Test loss:', score[0])
print('Test Accuracy:',score[1])





plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best'); plt.show()

x_new=np.zeros((2000,2))
z_new=np.zeros(2000)



for i in range(n_valid):
    x_new[i,0] = np.random.uniform(-3./2, 3./2.)
    x_new[i,1] = np.random.uniform(-3./2, 3./2.)

z_new = model.predict(x_new)
    
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x_new[:,0],x_new[:,1], z_new, c=z_new[:,0], marker = '.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(30,20)
plt.show()
# Out:
# 500/500 [==============================] - 0s 35us/sample - loss: 0.0561 - mean_squared_error: 0.0561
#
# Test loss: 0.05607835911214352
# Test Accuracy: 0.056078363
# 500/500 [==============================] - 0s 22us/sample - loss: 0.0180 - mean_squared_error: 0.0180
#
# Test loss: 0.017959709255956115
# Test Accuracy: 0.017959708
